# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random

random.seed(1301266)

# %%
# Interaction plot for tree result
plt.figure()
plt.title("Model Selection RMSE")
plt.xlabel("Feature set")
plt.ylabel("RMSE")
plt.plot(["1", "2", "3", "4"], [839.65, 839.65, 839.65, 839.65], marker='o', label="Baseline")
plt.plot(["1", "2", "3", "4"], [1047.05, 822.77, 987.25, 947.11], marker='o', label="DecisionTree")
plt.plot(["1", "2", "3", "4"], [693.65, 706.40, 723.52, 700.27], marker='o', label="AdaBoost")
plt.legend()
plt.show()
